# %% [markdown]
# ## D3. Maze: Optimize
#
# The pseudocode given in D1 has sub-optimal complexity.
#
# Optimize your solution for the previous problem (D2) if necessary, allowing it to run eﬃciently. Your solution will run on grids with larger size constraints: $1≤R≤1000, 1≤C≤1000$.
#
# ### Input format
#
# The same as in D2.
#
# ### Output format
#
# The same as in D2.

# %% [markdown]
# <div>
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">&nbsp;</div>
#     </div>
#   </div>
# </div>
# <div>
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <h4>Sample 1</h4>
#       </div>
#     </div>
#   </div>
# </div>
# <div>
#   <div data-mime-type="text/markdown">
#     <style>
#       .tg {
#         border-collapse: collapse;
#         border-spacing: 0;
#       }
#
#       .tg td {
#         border-color: black;
#         border-style: solid;
#         border-width: 1px;
#         font-family: Arial, sans-serif;
#         font-size: 14px;
#         overflow: hidden;
#         padding: 10px 5px;
#         word-break: normal;
#       }
#
#       .tg th {
#         border-color: black;
#         border-style: solid;
#         border-width: 1px;
#         font-family: Arial, sans-serif;
#         font-size: 14px;
#         font-weight: normal;
#         overflow: hidden;
#         padding: 10px 5px;
#         word-break: normal;
#       }
#
#       .tg .tg-snxj {
#         background-color: #FFF;
#         color: rgba(0, 0, 0, 0.87);
#         text-align: left;
#         vertical-align: middle
#       }
#
#       .tg .tg-aahv {
#         background-color: #E1F5FE;
#         color: rgba(0, 0, 0, 0.87);
#         text-align: left;
#         vertical-align: middle
#       }
#
#       .tg .tg-59uy {
#         background-color: #FFF;
#         color: rgba(0, 0, 0, 0.87);
#         font-weight: bold;
#         text-align: left;
#         vertical-align: middle
#       }
#
#       .tg .tg-cq2y {
#         background-color: #F5F5F5;
#         color: rgba(0, 0, 0, 0.87);
#         text-align: left;
#         vertical-align: middle
#       }
#     </style>
#     <table class="tg" style="margin-left: auto; margin-right: auto;">
#       <thead>
#         <tr>
#           <th class="tg-59uy"><span style="font-weight: bold;">Input</span></th>
#           <th class="tg-59uy"><span style="font-weight: bold;">Output</span></th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr>
#           <td class="tg-snxj">2 5</td>
#           <td class="tg-snxj">Yes</td>
#         </tr>
#         <tr>
#           <td class="tg-cq2y">. . # . .</td>
#           <td class="tg-cq2y">&nbsp;</td>
#         </tr>
#         <tr>
#           <td class="tg-aahv">. . . . #</td>
#           <td class="tg-aahv">&nbsp;</td>
#         </tr>
#       </tbody>
#     </table>
#     <div>
#       <div>
#         <div>
#           <div data-mime-type="text/markdown">
#             <h4>Sample 2</h4>
#             <div>&nbsp;</div>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div>
#       <div>
#         <div>
#           <style>
#             .tg {
#               border-collapse: collapse;
#               border-spacing: 0;
#             }
#
#             .tg td {
#               border-color: black;
#               border-style: solid;
#               border-width: 1px;
#               font-family: Arial, sans-serif;
#               font-size: 14px;
#               overflow: hidden;
#               padding: 10px 5px;
#               word-break: normal;
#             }
#
#             .tg th {
#               border-color: black;
#               border-style: solid;
#               border-width: 1px;
#               font-family: Arial, sans-serif;
#               font-size: 14px;
#               font-weight: normal;
#               overflow: hidden;
#               padding: 10px 5px;
#               word-break: normal;
#             }
#
#             .tg .tg-snxj {
#               background-color: #FFF;
#               color: rgba(0, 0, 0, 0.87);
#               text-align: left;
#               vertical-align: middle
#             }
#
#             .tg .tg-aahv {
#               background-color: #E1F5FE;
#               color: rgba(0, 0, 0, 0.87);
#               text-align: left;
#               vertical-align: middle
#             }
#
#             .tg .tg-59uy {
#               background-color: #FFF;
#               color: rgba(0, 0, 0, 0.87);
#               font-weight: bold;
#               text-align: left;
#               vertical-align: middle
#             }
#           </style>
#           <table class="tg" style="margin-left: auto; margin-right: auto;">
#             <thead>
#               <tr>
#                 <th class="tg-59uy"><span style="font-weight: bold;">Input</span></th>
#                 <th class="tg-59uy"><span style="font-weight: bold;">Output</span></th>
#               </tr>
#             </thead>
#             <tbody>
#               <tr>
#                 <td class="tg-snxj">1 3</td>
#                 <td class="tg-snxj">No</td>
#               </tr>
#               <tr>
#                 <td class="tg-aahv">. # .</td>
#                 <td class="tg-aahv">&nbsp;</td>
#               </tr>
#             </tbody>
#           </table>
#         </div>
#       </div>
#     </div>
#     <div>
#       <div>
#         <div>
#           <div data-mime-type="text/markdown">
#             <h4>Sample 3</h4>
#             <div>&nbsp;</div>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div>
#       <div>
#         <div>
#           <style>
#             .tg {
#               border-collapse: collapse;
#               border-spacing: 0;
#             }
#
#             .tg td {
#               border-color: black;
#               border-style: solid;
#               border-width: 1px;
#               font-family: Arial, sans-serif;
#               font-size: 14px;
#               overflow: hidden;
#               padding: 10px 5px;
#               word-break: normal;
#             }
#
#             .tg th {
#               border-color: black;
#               border-style: solid;
#               border-width: 1px;
#               font-family: Arial, sans-serif;
#               font-size: 14px;
#               font-weight: normal;
#               overflow: hidden;
#               padding: 10px 5px;
#               word-break: normal;
#             }
#
#             .tg .tg-snxj {
#               background-color: #FFF;
#               color: rgba(0, 0, 0, 0.87);
#               text-align: left;
#               vertical-align: middle
#             }
#
#             .tg .tg-aahv {
#               background-color: #E1F5FE;
#               color: rgba(0, 0, 0, 0.87);
#               text-align: left;
#               vertical-align: middle
#             }
#
#             .tg .tg-59uy {
#               background-color: #FFF;
#               color: rgba(0, 0, 0, 0.87);
#               font-weight: bold;
#               text-align: left;
#               vertical-align: middle
#             }
#
#             .tg .tg-cq2y {
#               background-color: #F5F5F5;
#               color: rgba(0, 0, 0, 0.87);
#               text-align: left;
#               vertical-align: middle
#             }
#           </style>
#           <table class="tg" style="margin-left: auto; margin-right: auto;">
#             <thead>
#               <tr>
#                 <th class="tg-59uy"><span style="font-weight: bold;">Input</span></th>
#                 <th class="tg-59uy"><span style="font-weight: bold;">Output</span></th>
#               </tr>
#             </thead>
#             <tbody>
#               <tr>
#                 <td class="tg-snxj">3 3</td>
#                 <td class="tg-snxj">No</td>
#               </tr>
#               <tr>
#                 <td class="tg-cq2y">. . #</td>
#                 <td class="tg-cq2y">&nbsp;</td>
#               </tr>
#               <tr>
#                 <td class="tg-snxj">. # .</td>
#                 <td class="tg-snxj">&nbsp;</td>
#               </tr>
#               <tr>
#                 <td class="tg-aahv"># . .</td>
#                 <td class="tg-aahv">&nbsp;</td>
#               </tr>
#             </tbody>
#           </table>
#         </div>
#       </div>
#     </div>
#     <div>
#       <div>
#         <div>
#           <div data-mime-type="text/markdown">
#             <h3>Notes</h3>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div>
#       <div>Maximum points for question <strong>D2</strong>:&nbsp;<strong>10</strong>&nbsp;points.</div>
#       <div data-mime-type="text/markdown">
#         <p><strong>Reminder:</strong><span>&nbsp;</span>You must select 2 out of 3 questions in programming section: Maze (D1-D3), Text (E1-E3), Titanic (F1-F3), and answer both selected questions as fully as possible.</p>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# |Input| Output|
# | :- | :-|
# |2 5 | Yes |
# |. . # . .| |
# |. . . . #| |

# %% [markdown]
# #### Sample 2

# %% [markdown]
# |Input| Output|
# | :- | :-|
# |1 3 | No |
# |. # .| |

# %% [markdown]
# #### Sample 3

# %% [markdown]
# |Input| Output|
# | :- | :-|
# |3 3 | No |
# |. . # | |
# |. # . | |
# |# . . | |

# %% [markdown]
# ### Notes
#
# Maximum points for question **D3**: **13** points.
#
# **Reminder:** You must select 2 out of 3 questions in programming section: Maze (D), Text (E), Titanic (F), and answer both selected questions as fully as possible (for example, if you choose Maze and Titanic, you should answer questions D1, D2, D3 and F1, F2, F3).

# %%
### Initial candidate answer code

# %%
# Use print("Debug messages...") to debug your solution.

def solution(inp):
    # Your code goes here
    return 'No'

# %%
### Initial candidate test code

# %%
example1 = ['2 5', '..#..', '....#']
print(example1) 
print(solution(example1), '\n')

example2 = ['1 3', '.#.']
print(example2) 
print(solution(example2), '\n')

example3 = ['3 3', '..#', '.#.', '#..']
print(example3) 
print(solution(example3), '\n')

# %%
### Autograder part (hidden from the candidate)

# %%
import numpy as np
import os

data_path = './datasets/D3/tests/'

for i in range(99):
    
    input_file = os.path.join(data_path,'{:02}'.format(i+1))
    output_file = os.path.join(data_path,'{:02}'.format(i+1)+'.a')
    with open(input_file) as f:
        data_in = f.read().splitlines()
    f.close()
    with open(output_file) as f:
        data_out = f.read().splitlines()
    f.close()
    
    sol = solution(data_in[0])
    ans = data_out[0]
    
    np.testing.assert_array_equal(sol,ans)
