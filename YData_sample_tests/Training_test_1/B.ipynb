# %% [markdown]
# <div data-windowed-list-index="15" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <h2>B1. Data interpretation</h2>
#       </div>
#     </div>
#   </div>
#   <div>A survey was performed to study the paying habits of a restaurant’s customers. Among 2500 meal orders, 30% were made by delivery, 20% by takeaway, and the rest were sit-down at the restaurant itself.</div>
# </div>
# <div data-windowed-list-index="16" aria-label="Markdown Cell Content">
#   <div>
#     <div data-mime-type="text/markdown">
#       <p>The table below shows the results in terms of the fraction of responders in each of the three categories (takeaway, delivery and sit-down).</p>
#     </div>
#   </div>
#   <style>
#     .tg {
#       border-collapse: collapse;
#       border-spacing: 0;
#     }
#
#     .tg td {
#       border-color: black;
#       border-style: solid;
#       border-width: 1px;
#       font-family: Arial, sans-serif;
#       font-size: 14px;
#       overflow: hidden;
#       padding: 10px 5px;
#       word-break: normal;
#     }
#
#     .tg th {
#       border-color: black;
#       border-style: solid;
#       border-width: 1px;
#       font-family: Arial, sans-serif;
#       font-size: 14px;
#       font-weight: normal;
#       overflow: hidden;
#       padding: 10px 5px;
#       word-break: normal;
#     }
#
#     .tg .tg-lboi {
#       border-color: inherit;
#       text-align: left;
#       vertical-align: middle
#     }
#
#     .tg .tg-9j3s {
#       border-color: inherit;
#       font-weight: bold;
#       text-align: right;
#       vertical-align: middle
#     }
#
#     .tg .tg-g7sd {
#       border-color: inherit;
#       font-weight: bold;
#       text-align: left;
#       vertical-align: middle
#     }
#
#     .tg .tg-yz93 {
#       border-color: inherit;
#       text-align: right;
#       vertical-align: middle
#     }
#   </style>
#   <table class="tg" style="margin-left: auto; margin-right: auto;">
#     <thead>
#       <tr>
#         <th class="tg-g7sd" style="text-align: center;">Order method</th>
#         <th class="tg-9j3s" style="text-align: center;">Paid in cash</th>
#         <th class="tg-9j3s" style="text-align: center;">Customer satisfied</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td class="tg-lboi">Take-away</td>
#         <td class="tg-yz93">0.25</td>
#         <td class="tg-yz93">0.55</td>
#       </tr>
#       <tr>
#         <td class="tg-lboi">Delivery</td>
#         <td class="tg-yz93">X</td>
#         <td class="tg-yz93">0.6</td>
#       </tr>
#       <tr>
#         <td class="tg-lboi">Sit-down</td>
#         <td class="tg-yz93">0.6</td>
#         <td class="tg-yz93">Y</td>
#       </tr>
#       <tr>
#         <td class="tg-lboi">Total</td>
#         <td class="tg-yz93">0.45</td>
#         <td class="tg-yz93">0.48</td>
#       </tr>
#     </tbody>
#   </table>
# </div>
# <div data-windowed-list-index="18" aria-label="Markdown Cell Content">
#   <div>&nbsp;</div>
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <p><strong>Q1</strong>. What is the ratio of the total number of sit-down orders paid for in cash to takeaway orders paid by means other than cash?</p>
#       </div>
#     </div>
#   </div>
# </div>
# <div data-windowed-list-index="19" aria-label="Markdown Cell Content">
#   <div>
#     <div><strong>Q2</strong>. If a given customer replied that they were satisﬁed with their meal, what is the probability that their meal was a delivery? (It is known that the mode of payment, customer satisfaction and order method are independent of each other).</div>
#   </div>
# </div>
# <div data-windowed-list-index="20" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <h3><span></span>Output format</h3>
#       </div>
#     </div>
#   </div>
# </div>
# <div data-windowed-list-index="21" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <p>INSTRUCTIONS: Read each question and ﬁnd the correct answer. Write the answers in the designated window, using the following format: Question number + space + correct answer (an irreducible ratio or a ﬂoating point number). Each answer should be in a separate row.</p>
#         <p>Example:<br>Q1 IRREDUCIBLE_RATIO<br>Q2 FP_NUMBER_WITH_EXACTLY_4_DECIMAL_DIGITS</p>
#       </div>
#     </div>
#   </div>
# </div>
# <div data-windowed-list-index="22" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <h3><span></span>Notes</h3>
#       </div>
#     </div>
#   </div>
# </div>
# <div data-windowed-list-index="23" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <p>Maximum points value for question<span>&nbsp;</span><strong>B1</strong>:<span>&nbsp;</span><strong>6</strong><span>&nbsp;</span>points</p>
#         <p>All numerical answers must be given with<span>&nbsp;</span><strong>exactly 4 decimal digits</strong>. e.g. if your solution is "1.5", your submitted answer should be "1.5000". If you do not solve some problems, you can skip the relevant questions in the submission window. "2:3" is an irreducible ratio while "5:15" is not.</p>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div data-windowed-list-index="24" aria-label="Markdown Cell Content">
#   <div>
#     <div>
#       <div data-mime-type="text/markdown">
#         <h2>B2. Data interpretation 2</h2>
#       </div>
#     </div>
#   </div>
# </div>
# <div data-windowed-list-index="25" aria-label="Markdown Cell Content">
#   <div style="text-align: left;">A city’s municipality has multiple departments. The information below pertains to ﬁve such departments: A, B, C, D, and E. All of the workers are paid on an hourly basis, and all members of the same department are paid the same, but the hourly wage of each department changes from month to month due to demand and budget constraints. Below is employment time and salary information by department for the months May-November, as well as a table with the total hours worked each month (across all departments). Answer the following questions based on this information:</div>
#   <div style="text-align: center;">&nbsp;</div>
# </div>
# <style>
#   .tg {
#     border-collapse: collapse;
#     border-spacing: 0;
#   }
#
#   .tg td {
#     border-color: black;
#     border-style: solid;
#     border-width: 1px;
#     font-family: Arial, sans-serif;
#     font-size: 14px;
#     overflow: hidden;
#     padding: 10px 5px;
#     word-break: normal;
#   }
#
#   .tg th {
#     border-color: black;
#     border-style: solid;
#     border-width: 1px;
#     font-family: Arial, sans-serif;
#     font-size: 14px;
#     font-weight: normal;
#     overflow: hidden;
#     padding: 10px 5px;
#     word-break: normal;
#   }
#
#   .tg .tg-snxj {
#     background-color: #FFF;
#     color: rgba(0, 0, 0, 0.87);
#     text-align: left;
#     vertical-align: middle
#   }
#
#   .tg .tg-613o {
#     background-color: #FFF;
#     border-color: inherit;
#     color: rgba(0, 0, 0, 0.87);
#     text-align: left;
#     vertical-align: middle
#   }
#
#   .tg .tg-lsmd {
#     background-color: #F5F5F5;
#     border-color: inherit;
#     color: rgba(0, 0, 0, 0.87);
#     text-align: left;
#     vertical-align: middle
#   }
#
#   .tg .tg-66kb {
#     background-color: #FFF;
#     border-color: inherit;
#     color: rgba(0, 0, 0, 0.87);
#     font-weight: bold;
#     text-align: left;
#     vertical-align: middle
#   }
#
#   .tg .tg-cq2y {
#     background-color: #F5F5F5;
#     color: rgba(0, 0, 0, 0.87);
#     text-align: left;
#     vertical-align: middle
#   }
# </style>
# <table class="tg" style="margin-left: auto; margin-right: auto;">
#   <thead>
#     <tr>
#       <th class="tg-66kb"><span style="font-weight: bold;">MONTH</span></th>
#       <th class="tg-66kb"><span style="font-weight: bold;">TOTAL HOURS</span></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td class="tg-613o">MAY</td>
#       <td class="tg-613o">1600</td>
#     </tr>
#     <tr>
#       <td class="tg-lsmd">JUN</td>
#       <td class="tg-lsmd">1500</td>
#     </tr>
#     <tr>
#       <td class="tg-613o">JUL</td>
#       <td class="tg-613o">2100</td>
#     </tr>
#     <tr>
#       <td class="tg-lsmd">AUG</td>
#       <td class="tg-lsmd">2600</td>
#     </tr>
#     <tr>
#       <td class="tg-snxj">SEP</td>
#       <td class="tg-snxj">2200</td>
#     </tr>
#     <tr>
#       <td class="tg-cq2y">OCT</td>
#       <td class="tg-cq2y">1800</td>
#     </tr>
#     <tr>
#       <td class="tg-snxj">NOV</td>
#       <td class="tg-snxj">2500</td>
#     </tr>
#   </tbody>
# </table>
# <div data-windowed-list-index="26" aria-label="Markdown Cell Content">
#   <div>&nbsp;</div>
# </div>
# <div data-windowed-list-index="27" aria-label="Markdown Cell Content">
#   <div data-mime-type="text/markdown">
#     <p><img src="./images/image1.png" alt="Image" width="500" height="300"><span>&nbsp;</span><img src="./images/image2.png" alt="Image" width="500" height="300"></p>
#     <p>&nbsp;</p>
#     <div data-windowed-list-index="28" aria-label="Markdown Cell Content">
#       <div data-mime-type="text/markdown">
#         <div data-windowed-list-index="28" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p><strong>Q1</strong>. In what month have department B employees worked the most hours?</p>
#                 <p>A. May<br>B. June<br>C. August<br>D. October<br>E. November</p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="29" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p><strong>Q2</strong>. What is the ratio between the number of department C man-hours in May and department E man-hours in Oct?</p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="30" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p><strong>Q3</strong>. Over the period from May till August, which department had the most stable work load?</p>
#                 <p>A. Department A<br>B. Department B<br>C. Department C<br>D. Department D<br>E. Department E</p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="31" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p><em>Which department is which?</em></p>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div data-windowed-list-index="32" aria-label="Markdown Cell Content">
#       <div data-mime-type="text/markdown">
#         <div data-windowed-list-index="32" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p><strong>Q4</strong>. The employees of veterinary services department were very disgruntled after receiving September salary, and many of them quit. Which department is veterinary services?</p>
#                 <p>A. Department A<br>B. Department B<br>C. Department C<br>D. Department D<br>E. Department E</p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="33" aria-label="Markdown Cell Content">
#           <div>
#             <div><strong>Q5</strong>. It is commonly known that no matter how the salaries change over time, the employees of accounting department are always the best paid. Which department is accounting?</div>
#             <div data-mime-type="text/markdown">
#               <p>A. Department A<br>B. Department B<br>C. Department C<br>D. Department D<br>E. Department E</p>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="34" aria-label="Markdown Cell Content">
#           <div><strong>Q6</strong>. Which of the following is lifeguard services department?</div>
#           <div data-mime-type="text/markdown">
#             <p>A. Department A<br>B. Department B<br>C. Department C<br>D. Department D<br>E. Department E</p>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div data-windowed-list-index="35" aria-label="Markdown Cell Content">
#       <div data-mime-type="text/markdown">
#         <div data-windowed-list-index="35" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <h3>Output format</h3>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="36" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p>INSTRUCTIONS: Read each question and ﬁnd the correct answer. Write the answers in the designated window, using the following format: Question number + space + correct answer (an irreducible ratio or a letter). Each answer should be in a separate row.</p>
#                 <p>Example:<br>Q1 A<br>Q2 IRREDUCIBLE_RATIO<br>Q3 A<br>Q4 A<br>Q5 A<br>Q6 A</p>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="37" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <h3><span></span>Notes</h3>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div data-windowed-list-index="38" aria-label="Markdown Cell Content">
#           <div>
#             <div>
#               <div data-mime-type="text/markdown">
#                 <p>Maximum points value for question<span>&nbsp;</span><strong>B2</strong>:<span>&nbsp;</span><strong>10</strong><span>&nbsp;</span>points</p>
#                 <p>You can output any number of answers, if you do not solve some problems. Ratio "2:3" is irreducible while "5:15" is not.</p>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
