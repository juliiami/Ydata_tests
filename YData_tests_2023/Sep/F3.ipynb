# %% [markdown]
# <div class="problem-statement">
#   <div class="header">
#     <h1 class="title">(F3) Streaming:&nbsp;Profile</h1>
#   </div>
#   <div class="legend">In this question you are required to <span style="font-weight: bold;">write code</span>, implementing a solution to the following problem. <!--l. 52-->
#     <p style="text-indent: 0em;">In the working directory there is a ﬁle <span style="font-family: monospace;">stream_data.csv, </span>which you used in the previous question.</p>
#     <p style="text-indent: 0em;"><span style="font-family: monospace;"></span><!--l. 56--></p>
#     <p>You’re tasked with assigning <strong>"proﬁles" </strong>to individual channels based on their performance, diﬀerentiating between channels with diﬀerent behaviour types. You will then be asked to retrieve the top channel suiting a given proﬁle and language combination.</p>
#     <p>To create the proﬁles, ﬁnd the top 10% of channels in the dataset for each of the following metrics:</p>
#     <p><img style="display: block; margin-left: auto; margin-right: auto;" src="https://www.codingame.com/work/servlet/fileservlet?id=58583535968251" alt="" width="555" height="300"></p>
#     <p>Given a target language and proﬁle (<code>Language</code> and <code>Profile Tag</code>), return the top-ranking channel with the desired proﬁle in the target language. Use best <strong>average</strong>&nbsp;<strong>rank </strong>(calculated in F1) to determine which channel to return.</p>
#     <p>Return 0 if there are no channels found for the target language and proﬁle.</p>
#   </div>
#   <h2>Input format</h2>
#   <div class="input-specification">
#     <p>Two words separated by space, corresponding to target language and proﬁle (<code>Language</code> and <code>Profile Tag</code>).</p>
#     <!--l. 69-->
#     <p style="text-indent: 0em;"><span style="font-weight: bold;">Data</span>:<br><span style="font-family: monospace;">stream_data.csv</span>, which was used in the previous question (F1).</p>
#   </div>
#   <h2>Output format</h2>
#   <div class="output-specification">
#     <p>Return one integer value: the <code>ChannelID</code> of the top channel.</p>
#     <p>Return 0 if no suitable channels are available for the proﬁle and language.</p>
#   </div>
#   <h3>Sample 1</h3>
#   <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#     <thead>
#       <tr>
#         <th style="border: 2px solid #fff;">Input</th>
#         <th style="border: 2px solid #fff;">Output</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre class="content">English FG</pre>
#         </td>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre>20651</pre>
#         </td>
#       </tr>
#     </tbody>
#   </table>
#   <div>
#     <h3>Sample 2</h3>
#     <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#       <thead>
#         <tr>
#           <th style="border: 2px solid #fff;">Input</th>
#           <th style="border: 2px solid #fff;">Output</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre class="content">Italian OHW</pre>
#           </td>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre>27173</pre>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
#   <div>
#     <h3>Sample 3</h3>
#     <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#       <thead>
#         <tr>
#           <th style="border: 2px solid #fff;">Input</th>
#           <th style="border: 2px solid #fff;">Output</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre class="content">Czech OHW</pre>
#           </td>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre>0</pre>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
#   <h3>Notes</h3>
#   <div class="notes">Maximum points for question F3: <span style="font-weight: bold;">13 </span>points.</div>
#   <div class="notes">&nbsp;</div>
#   <div class="notes"><!--l. 80-->
#     <p style="text-indent: 0em;"><span style="font-weight: bold;">Reminder: </span>You must select 2 out of 3 questions in programming section: Sums (D), Countries (E), Streaming (F), and answer both selected questions as fully as possible (for example, if you choose Sums and Streaming, you should answer questions D1, D2, D3 and F1, F2, F3).</p>
#   </div>
# </div>

# %%
### Initial candidate answer code

# %%
# Use print("messages...") to debug your solution.
import numpy as np
import pandas as pd

stream_data = pd.read_csv('./datasets/F3/stream_data.csv', sep=",")

def solution(Language, Profile):
    # Your code goes here
    return 0

# %%
### Initial candidate test code

# %%
import numpy as np
import pandas as pd
from datetime import datetime

stream_data = pd.read_csv('./datasets/F3/stream_data.csv', sep=",")
print(stream_data.head())

print(solution('English','FG'), '\n')

print(solution('Italian','OHW'), '\n')

print(solution('Czech','OHW'), '\n')

# %%
### Autograder part (hidden from the candidate)

# %%
import numpy as np
import os

data_path = './datasets/F3/tests/'

for i in range(10):
    
    input_file = os.path.join(data_path,'{:02}'.format(i+1))
    output_file = os.path.join(data_path,'{:02}'.format(i+1)+'.a')
    with open(input_file) as f:
        data_in = f.read().splitlines()
    f.close()
    with open(output_file) as f:
        data_out = f.read().splitlines()
    f.close()

    
    q = data_in[0].split()
    a = float(data_out[0])
    sol = solution(q[0], q[1])
    
    np.testing.assert_array_equal(sol,a)
